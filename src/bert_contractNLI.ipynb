# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.29.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)

# %%
import torch
from tqdm import tqdm

SEED = 1111
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
from transformers import AutoTokenizer
model_name='bert-base-uncased'

tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
init_token = tokenizer.cls_token
eos_token = tokenizer.sep_token
pad_token = tokenizer.pad_token
unk_token = tokenizer.unk_token
additional_tokens = []
print(init_token, eos_token, pad_token, unk_token)
# Out:
# [CLS] [SEP] [PAD] [UNK]

# %%
init_token_idx = tokenizer.cls_token_id
eos_token_idx = tokenizer.sep_token_id
pad_token_idx = tokenizer.pad_token_id
unk_token_idx = tokenizer.unk_token_id

print(init_token_idx, eos_token_idx, pad_token_idx, unk_token_idx)
# Out:
# 101 102 0 100

# %%
max_input_length = 63

# %%
def tokenize_bert(sentence):
    tokens = tokenizer.tokenize(sentence) 
    return tokens

# %%
def split_and_cut(sentence):
    tokens = sentence.strip().split(" ")
    tokens = tokens[:max_input_length-1]
    return tokens

# %%
def trim_sentence(sent):
    try:
        sent = sent.split()
        sent = sent[:32]
        return " ".join(sent)
    except:
        return sent

# %%
# !wget https://stanfordnlp.github.io/contract-nli/resources/contract-nli.zip
# Out:
# --2023-05-15 05:32:03--  https://stanfordnlp.github.io/contract-nli/resources/contract-nli.zip
# Resolving stanfordnlp.github.io (stanfordnlp.github.io)... 185.199.108.153, 185.199.110.153, 185.199.111.153, ...
# Connecting to stanfordnlp.github.io (stanfordnlp.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65362913 (62M) [application/zip]
# Saving to: ‘contract-nli.zip.3’
#
# contract-nli.zip.3  100%[===================>]  62.33M   331MB/s    in 0.2s
#
# 2023-05-15 05:32:04 (331 MB/s) - ‘contract-nli.zip.3’ saved [65362913/65362913]

# %%
from zipfile import ZipFile
  
# specifying the zip file name
file_name = "contract-nli.zip"
  
# opening the zip file in READ mode
with ZipFile(file_name, 'r') as zip:
    # printing all the contents of the zip file
    zip.printdir()
  
    # extracting all the files
    print('Extracting all the files now...')
    zip.extractall()
    print('Done!')
# Out:
# File Name                                             Modified             Size
# contract-nli/                                  2021-10-06 01:32:08            0
# contract-nli/LICENSE                           2021-10-04 17:59:52        18656
# contract-nli/TERMS                             2021-10-04 19:39:12         3664
# contract-nli/test.json                         2021-10-06 01:32:02      2260203
# contract-nli/dev.json                          2021-10-06 01:32:08      1183107
# contract-nli/README.md                         2021-10-05 20:05:32         5561
# contract-nli/train.json                        2021-10-06 01:32:06      7608211
# contract-nli/raw/                              2021-10-04 17:58:02            0
# contract-nli/raw/NDA%2009%20for%20website.pdf  2021-10-04 17:57:32       102888
# contract-nli/raw/Non-Disclosure-Agreement_12.pdf 2021-10-04 17:57:32       387795
# contract-nli/raw/NDA-ROI-Corporation.pdf       2021-10-04 17:57:32        71906
# contract-nli/raw/stony_hill_buyer_nda.pdf      2021-10-04 17:57:32        60439
# contract-nli/raw/IPTK-CO-MutualNon-DisclosureAgreement.pdf 2021-10-04 17:57:32       126567
# contract-nli/raw/Non-disclosure.pdf            2021-10-04 17:57:32       106535
# contract-nli/raw/1125892_0000950133-00-004441_w41075a1ex10-7.txt 2021-10-04 17:58:02        17924
# contract-nli/raw/confagree.pdf                 2021-10-04 17:57:46       128093
# contract-nli/raw/1103062_0001017951-00-000016_document_13.txt 2021-10-04 17:57:32        11478
# contract-nli/raw/ATI%20504%20US%20Mutual%20NDA.pdf 2021-10-04 17:57:46        23320
# contract-nli/raw/CBP%20Non-Disclosure%20Form_October2018.pdf 2021-10-04 17:58:00       105025
# contract-nli/raw/1101204_0001085037-00-000208_0015.txt 2021-10-04 17:57:32         8167
# contract-nli/raw/pp%2011%20-%20non-disclosure%20agreement%20mutual.pdf 2021-10-04 17:57:32       233328
# contract-nli/raw/Confidentiality%20and%20Non-Disclosure%20Agreement.pdf 2021-10-04 17:57:46       107352
# contract-nli/raw/1068874_0001068874-07-000012_ex10_2.htm 2021-10-04 17:57:32        47239
# contract-nli/raw/ccporappdev-rfp-att8.pdf      2021-10-04 17:57:46        23204
# contract-nli/raw/MNDA-V2-2-25-15.pdf           2021-10-04 17:57:32        70961
# contract-nli/raw/1108906_0000889812-00-001212_document_45.txt 2021-10-04 17:57:32         6155
# contract-nli/raw/916457_0000916457-14-000028_exhibit104-confidentiality.htm 2021-10-04 17:58:02        37673
# contract-nli/raw/1163932_0001193125-13-394191_d606730dex99d2.htm 2021-10-04 17:57:32        37728
# contract-nli/raw/Non-Disclosure-Agreement-1.pdf 2021-10-04 17:57:32       121409
# contract-nli/raw/1013687_0000950144-96-001973_document_37.txt 2021-10-04 17:57:32         4852
# contract-nli/raw/913610_0001047469-03-027395_a2116567zex-99_e3.htm 2021-10-04 17:57:32        27379
# contract-nli/raw/Non-disclosure%20Agreement_1.pdf 2021-10-04 17:57:32       168752
# contract-nli/raw/Non Disclosure Agreement - CP Specific NDA (CreativeNDA-CPS121.1014).pdf 2021-10-04 17:57:32       168485
# contract-nli/raw/1082797_0000950131-01-501837_dex99d2.txt 2021-10-04 17:57:32         8415
# contract-nli/raw/NDA-Broker-Seller-for-Company-6-19-17.pdf 2021-10-04 17:57:32        92284
# contract-nli/raw/Supplier_Non_Disclosure.pdf   2021-10-04 17:57:32       133466
# contract-nli/raw/881790_0001104659-12-052730_a12-17284_1ex99d1.htm 2021-10-04 17:57:32        42590
# contract-nli/raw/880562_0001193125-15-346821_d93800dex3.htm 2021-10-04 17:57:32        33479
# contract-nli/raw/Agency-Lending-Disclosure_A-Z-Guide_Appendix_Sample-Confidentiality-Agreements.pdf 2021-10-04 17:58:00       382922
# contract-nli/raw/NON-DISCLOSURE-AGREEMENT_13.pdf 2021-10-04 17:57:32       146309
# contract-nli/raw/865415_0001047469-15-007494_a2226057zex-99_d4.htm 2021-10-04 17:57:32        32544
# contract-nli/raw/Non_Disclosure_Canada_BC.pdf  2021-10-04 17:57:32        87404
# contract-nli/raw/1041550_0001193125-19-004977_d663808dex106.htm 2021-10-04 17:58:02        58263
# contract-nli/raw/1084000_0001144204-06-046785_v056501_ex10-16.txt 2021-10-04 17:58:02         8303
# contract-nli/raw/Non-Disclosure%20Agreement%202015.pdf 2021-10-04 17:57:32       320333
# contract-nli/raw/NCDG_Non-disclosure-agreement.pdf 2021-10-04 17:57:32        84944
# contract-nli/raw/1104332_0000950144-00-008876_ex10-26.txt 2021-10-04 17:57:46         7850
# contract-nli/raw/828957_0000950109-98-001266_document_19.txt 2021-10-04 17:57:32        13159
# contract-nli/raw/sample-nrel-bilateral-nda-template.pdf 2021-10-04 17:57:32       655160
# contract-nli/raw/isca-nda.pdf                  2021-10-04 17:57:32       135108
# contract-nli/raw/Non-Disclosure-Agreement_11.pdf 2021-10-04 17:57:32       637693
# contract-nli/raw/1173495_0001047469-03-033872_a2118144zex-10_12.txt 2021-10-04 17:58:02        12538
# contract-nli/raw/NDA_VPI.pdf                   2021-10-04 17:57:32       149689
# contract-nli/raw/09-24-2019-04-25-05-3914910473.pdf 2021-10-04 17:57:46       404472
# contract-nli/raw/Non-Disclosure%20Agreement_3.pdf 2021-10-04 17:57:32        92046
# contract-nli/raw/1100772_0001038838-02-000125_ex1032sb2no5.txt 2021-10-04 17:57:46         6278
# contract-nli/raw/MutualNonDisclosureAgreement0104.pdf 2021-10-04 17:57:32        39350
# contract-nli/raw/1452751_0001193125-17-086167_d334994dex99e3.htm 2021-10-04 17:57:46        26361
# contract-nli/raw/Non-Disclosure-Agreement_ALL_englisch.pdf 2021-10-04 17:57:32        63212
# contract-nli/raw/BOMI%20Non-Disclosure%20Agreement.pdf 2021-10-04 17:57:46        12743
# contract-nli/raw/Non-Discl_Reciprocal_2.pdf    2021-10-04 17:57:32        92977
# contract-nli/raw/nda_16.pdf                    2021-10-04 17:57:32        65807
# contract-nli/raw/918541_0001193125-14-328980_d785003dex105.htm 2021-10-04 17:57:32        28013
# contract-nli/raw/1053374_0001144204-18-062970_tv508217_ex-d2.htm 2021-10-04 17:57:32        31275
# contract-nli/raw/1240722_0001161697-03-000454_exhibit_10-12.txt 2021-10-04 17:57:32        11921
# contract-nli/raw/Supplier_Non-Disclosure_Agreement.pdf 2021-10-04 17:57:32       107477
# contract-nli/raw/Kenway-NDA-Form-Blank.pdf     2021-10-04 17:57:32       225878
# contract-nli/raw/Facility-Tour-Confidentiality-and-Non-Disclosure.pdf 2021-10-04 17:57:32       208502
# contract-nli/raw/Project%20LAS%20RFI%20Non-Disclosure%20Agreement.pdf 2021-10-04 17:57:32       182045
# contract-nli/raw/1020416_0001193125-16-701566_d250247dex99d2.htm 2021-10-04 17:58:02        46532
# contract-nli/raw/ConfidNonDisclosureAgree.pdf  2021-10-04 17:58:02        40404
# contract-nli/raw/NDA_17.pdf                    2021-10-04 17:57:32       179155
# contract-nli/raw/899240_0000912057-01-007226_a2040095zex-99_9d1.txt 2021-10-04 17:57:32        11825
# contract-nli/raw/20150916-model-sharing-non-disclosure-agreement.pdf 2021-10-04 17:57:46       169461
# contract-nli/raw/Proctor_Agreement.pdf         2021-10-04 17:57:32        59593
# contract-nli/raw/88190_0000950144-96-003474_document_2.txt 2021-10-04 17:57:46        17161
# contract-nli/raw/Non-disclosure%20agreement_2.pdf 2021-10-04 17:57:32       205401
# contract-nli/raw/814457_0000950137-04-009790_c89545exv99wxdyx6y.htm 2021-10-04 17:58:02        23580
# contract-nli/raw/1125576_0000928385-02-000738_dex991d2.txt 2021-10-04 17:57:32         5340
# contract-nli/raw/confidentiality_agreement.pdf 2021-10-04 17:58:02        87958
# contract-nli/raw/845818_0001193125-11-195725_dex99d8.htm 2021-10-04 17:57:32        30494
# contract-nli/raw/55805_0001145443-10-001028_d26631_ex99-d3.htm 2021-10-04 17:57:32        31826
# contract-nli/raw/Non-Disclosure-Agreement-v1.pdf 2021-10-04 17:57:32       334079
# contract-nli/raw/Non-Disclosure-Agreement_10.pdf 2021-10-04 17:57:32        76750
# contract-nli/raw/313522_0000912057-02-040085_a2091647zex-99_d3.htm 2021-10-04 17:57:46        11668
# contract-nli/raw/MutualNDA_The_Knights_of_Unity.pdf 2021-10-04 17:57:32       147688
# contract-nli/raw/NDA-Dollar-General-Portfolio.pdf 2021-10-04 17:57:32       149544
# contract-nli/raw/118.3-Non-disclosure-agreement.pdf 2021-10-04 17:58:00        12273
# contract-nli/raw/nda-format-approved-by-legal-section.pdf 2021-10-04 17:57:32       227189
# contract-nli/raw/736291_0000930661-99-001320_document_3.txt 2021-10-04 17:57:32        23510
# contract-nli/raw/Geheimhaltungsvereinbarung_Abschlussarbeiten_HFU_englisch.pdf 2021-10-04 17:57:32       218162
# contract-nli/raw/24104_0000024104-96-000010_document_3.txt 2021-10-04 17:57:32         9559
# contract-nli/raw/1077050_0000950147-99-000049_document_10.txt 2021-10-04 17:57:32        11810
# contract-nli/raw/CON-NDA-PTL-01-2012-v1%20Non-Disclosure%20Agreement%20and%20Checklist.pdf 2021-10-04 17:58:02       152395
# contract-nli/raw/Sony%20Pictures%20Television%20NDA%20(Executed).pdf 2021-10-04 17:57:32       312031
# contract-nli/raw/standard_nda.pdf              2021-10-04 17:57:32       141997
# contract-nli/raw/1061148_0001047469-98-018914_document_17.txt 2021-10-04 17:57:32        13362
# contract-nli/raw/NEW_moi_ndform.pdf            2021-10-04 17:57:32        63826
# contract-nli/raw/Bio-FIP-EOI-NDA.pdf           2021-10-04 17:58:00       110919
# contract-nli/raw/confidentiality-agreement.pdf 2021-10-04 17:58:02       106939
# contract-nli/raw/FSMAApprovedConfidentiality-MutualDistributor-FSMA4002.pdf 2021-10-04 17:57:32       215528
# contract-nli/raw/87814_0000930661-96-001456_document_4.txt 2021-10-04 17:57:32        84045
# contract-nli/raw/NDA_13.pdf                    2021-10-04 17:57:32       115410
# contract-nli/raw/1457829_0000898822-13-000086_exhibit-ndaexecutionversion.htm 2021-10-04 17:58:02        59273
# contract-nli/raw/ConfidentialityAgreement.pdf  2021-10-04 17:58:02        49306
# contract-nli/raw/Mutual_Nondisclosure_Agreement.pdf 2021-10-04 17:57:32       173303
# contract-nli/raw/NDA-Template-Media-News-Group-inc.pdf 2021-10-04 17:58:02        29931
# contract-nli/raw/931784_0001104659-07-068716_a07-23871_1ex2.htm 2021-10-04 17:57:32        37795
# contract-nli/raw/Mutual%20NDA_Confidentiality.pdf 2021-10-04 17:57:32        24880
# contract-nli/raw/SAMED%20confidentiality%20non%20disclosure%20and%20conflict%20of%20interest%20agreement%20for%20board%20and%20committee%20members%20ver%201.pdf 2021-10-04 17:58:02       150034
# contract-nli/raw/Non%20Disclosure%20Agreement_1.pdf 2021-10-04 17:57:32        69358
# contract-nli/raw/1693664_0001193125-18-171470_d426098dex99d3.htm 2021-10-04 17:57:32        38165
# contract-nli/raw/SINTEC-UK-LTD-Non-disclosure-agreement-2017.pdf 2021-10-04 17:57:32      1372115
# contract-nli/raw/nda-employee-template.pdf     2021-10-04 17:57:32        30599
# contract-nli/raw/917253_0000917253-00-000008_document_8.txt 2021-10-04 17:57:32        23978
# contract-nli/raw/25895_0000950134-07-023464_d51356exv10w1.htm 2021-10-04 17:57:32        28736
# contract-nli/raw/MR_NON-DISCLOSURE-AGREEMENT.pdf 2021-10-04 17:57:32        68424
# contract-nli/raw/922237_0000950005-02-000645_p15515_ex10-19.txt 2021-10-04 17:57:32         8692
# contract-nli/raw/912643_0001045969-00-000244_document_3.txt 2021-10-04 17:57:32         8061
# contract-nli/raw/1089717_0000898430-99-004004_document_2.txt 2021-10-04 17:57:32         8777
# contract-nli/raw/NDA_Street_Stream_Franchise.pdf 2021-10-04 17:58:02       120941
# contract-nli/raw/426-2017_Appendix_C-Sample_Non-Disclosure_Agreement.pdf 2021-10-04 17:57:46        19717
# contract-nli/raw/New_York_City_Bar_Association_Model_Form_of_Non-Disclosure_Agreement_2015.pdf 2021-10-04 17:57:32       183503
# contract-nli/raw/1277090_0001104659-05-057084_a05-20673_1ex10.htm 2021-10-04 17:57:32        48821
# contract-nli/raw/925544_0000950144-00-010739_ex99-d4.txt 2021-10-04 17:57:32         8694
# contract-nli/raw/AICPMutualNDA_1219166_writableV2.pdf 2021-10-04 17:57:46        90440
# contract-nli/raw/Attachment%203%20-%20Confidentiality%20Release%20Form_201504131404512865.pdf 2021-10-04 17:57:46       122873
# contract-nli/raw/1561604_0001193125-12-472390_d438799dex99d3.htm 2021-10-04 17:57:32        43815
# contract-nli/raw/Confidentiality%20Non-Disclosure%20and%20Appropriate%20Use%20Agreement%20-%20FAU.01082016.pdf 2021-10-04 17:57:46       129376
# contract-nli/raw/Non_disclodure_contract.pdf   2021-10-04 17:57:32        35314
# contract-nli/raw/helpjuice_production%2Fuploads%2Fupload%2Fimage%2F2329%2Fdirect%2F1526996160411-FullStory+Mutual+Non-Disclosure+Agreement+2018.pdf 2021-10-04 17:57:32        83202
# contract-nli/raw/Non-Disclosure%20Agreement_5.pdf 2021-10-04 17:57:32       116882
# contract-nli/raw/109261_0000950172-02-002217_los283194.txt 2021-10-04 17:57:46        16125
# contract-nli/raw/1014959_0000950116-96-000618_document_7.txt 2021-10-04 17:57:32        12173
# contract-nli/raw/NDA_10.pdf                    2021-10-04 17:57:32        93924
# contract-nli/raw/AGProjects-NDA.pdf            2021-10-04 17:58:00        94023
# contract-nli/raw/1095563_0000950168-99-002585_document_2.txt 2021-10-04 17:57:32        12879
# contract-nli/raw/Annexure-3_Confidentiality-Agreement.pdf 2021-10-04 17:57:46       120054
# contract-nli/raw/nda_11.pdf                    2021-10-04 17:57:32       113066
# contract-nli/raw/nda_form_motorola.pdf         2021-10-04 17:57:32        68639
# contract-nli/raw/NDA_and_assgmnt_of_ipMar2011.pdf 2021-10-04 17:57:32        30533
# contract-nli/raw/NDA-Instructions-Agreement-Attachment.pdf 2021-10-04 17:57:32       126553
# contract-nli/raw/1052946_0000950134-98-001627_document_4.txt 2021-10-04 17:57:32         3044
# contract-nli/raw/1096147_0001193125-08-206038_dex4.htm 2021-10-04 17:58:02        40236
# contract-nli/raw/1094038_0000950134-05-007541_d23996exv10w4.htm 2021-10-04 17:57:32        15896
# contract-nli/raw/1329919_0001193125-14-149149_d701401dex99d6.htm 2021-10-04 17:57:32        47500
# contract-nli/raw/Confidentiality_and_Non-Disclosure_Agreement_Rev_10-20-16.pdf 2021-10-04 17:58:02        38838
# contract-nli/raw/non-disclosure-agreement-to-public-tender-for-fleet-and-bus-services-f-2854607.pdf 2021-10-04 17:57:32       279849
# contract-nli/raw/CopAcc_NDA-and-ToP-Mentors_2.0_2017.pdf 2021-10-04 17:57:32       603796
# contract-nli/raw/Clause-de-non-divulgation.pdf 2021-10-04 17:58:02        94000
# contract-nli/raw/C_TERMS_NDA_EN.pdf            2021-10-04 17:57:46        96915
# contract-nli/raw/nondisclosure-Engl.pdf        2021-10-04 17:57:32        21613
# contract-nli/raw/One_way_NDA_EIPRHD_pdf_v1_11.03.2013.pdf 2021-10-04 17:57:32       282806
# contract-nli/raw/Roundhouse-Creative-Mutual-NDA.pdf 2021-10-04 17:57:32        65251
# contract-nli/raw/annex-iii---nda-agreement..pdf 2021-10-04 17:58:00       154163
# contract-nli/raw/Aspiegel_NDA_template.pdf     2021-10-04 17:58:00       165783
# contract-nli/raw/1094814_0001140361-18-017998_s002178x1_ex99d7.htm 2021-10-04 17:57:46        66154
# contract-nli/raw/icc-court-non-disclosure-agreement-english.pdf 2021-10-04 17:57:32       228311
# contract-nli/raw/non-disclosure-agreement_2.pdf 2021-10-04 17:57:32       119738
# contract-nli/raw/NonDisclosureAgreement_1.pdf  2021-10-04 17:57:32       228840
# contract-nli/raw/1094007_0001193125-10-258977_dex101.htm 2021-10-04 17:57:32        36437
# contract-nli/raw/khronos-mutual-nda.pdf        2021-10-04 17:57:32       102551
# contract-nli/raw/1487101_0001140361-19-008970_nc10001202x4_ex-d2.htm 2021-10-04 17:57:32        47192
# contract-nli/raw/Non-Disclosure-Secrecy-Agreement.pdf 2021-10-04 17:58:02        25029
# contract-nli/raw/922913_0000943440-00-000294_0004.txt 2021-10-04 17:57:32         4443
# contract-nli/raw/resources-non-disclosure-agreement.pdf 2021-10-04 17:57:32        91486
# contract-nli/raw/non-disclosure_agreement.pdf  2021-10-04 17:57:32         8333
# contract-nli/raw/Non_Disclosure_Agreement_3.pdf 2021-10-04 17:57:32       292310
# contract-nli/raw/Data_Use_and_Non_Disclosure_Data_Disclosed_to_MDCH_Trauma_Registry_Final_465518_7.pdf 2021-10-04 17:58:02        18821
# contract-nli/raw/nda_2.pdf                     2021-10-04 17:57:32        23880
# contract-nli/raw/768262_0001193125-10-128597_dex99d2.htm 2021-10-04 17:57:32        36773
# contract-nli/raw/Inaturals_NDA.pdf             2021-10-04 17:57:32       108243
# contract-nli/raw/NDA-STP-Performance-Coating-revC.pdf 2021-10-04 17:57:32        37276
# contract-nli/raw/1089029_0000950123-07-007908_y31303a1exv10w13.htm 2021-10-04 17:57:32         8703
# contract-nli/raw/799485_0000950136-00-001643_0013.txt 2021-10-04 17:57:32        17036
# contract-nli/raw/JB-Machine-LLC-NDA-1.pdf      2021-10-04 17:57:32       196200
# contract-nli/raw/1366649_0001193125-14-380778_d808213dex99d2.htm 2021-10-04 17:57:46        20004
# contract-nli/raw/1473637_0001432093-12-000764_ex10-34.htm 2021-10-04 17:57:32        28489
# contract-nli/raw/wayne-fueling-systems-mutual-non-disclosure-agreement-final.pdf 2021-10-04 17:57:32        36894
# contract-nli/raw/SONGS%20RFP%20Confidentiality%20Agreement_201705051754392249.pdf 2021-10-04 17:57:32        57226
# contract-nli/raw/Sample NonDisclosure Agreement.pdf 2021-10-04 17:57:32       124624
# contract-nli/raw/annex-2-sample-non-disclosure-agreement.pdf 2021-10-04 17:57:46       518726
# contract-nli/raw/tpi-non-disclosure-agreement_1.pdf 2021-10-04 17:57:32        32675
# contract-nli/raw/1175638_0000912057-02-024619_a2082526zex-10_3.htm 2021-10-04 17:57:32        11582
# contract-nli/raw/nda_3.pdf                     2021-10-04 17:57:32       131294
# contract-nli/raw/NDA-2015-2.pdf                2021-10-04 17:57:32        84198
# contract-nli/raw/1002276_0001036050-99-002047_document_13.txt 2021-10-04 17:58:02        10865
# contract-nli/raw/mutual-non-disclosure-agreement.pdf 2021-10-04 17:58:02       294666
# contract-nli/raw/Non_Disclosure_Agreement_2.pdf 2021-10-04 17:57:32       174380
# contract-nli/raw/1112422_0000950153-08-001257_p75864exv99wxeyx4y.htm 2021-10-04 17:57:32        42294
# contract-nli/raw/NDA_eng.pdf                   2021-10-04 17:57:32        55164
# contract-nli/raw/Mutual-Non-Disclosure-Agreement-EN.pdf 2021-10-04 17:57:32       434699
# contract-nli/raw/contrato_ingles_corporativo_mal.pdf 2021-10-04 17:57:32       237290
# contract-nli/raw/Non-Disclosure-Agreement_3.pdf 2021-10-04 17:57:32       346801
# contract-nli/raw/NDCA.pdf                      2021-10-04 17:57:32        61486
# contract-nli/raw/QSA_NDA.pdf                   2021-10-04 17:57:32        35734
# contract-nli/raw/O00216-000899A.pdf            2021-10-04 17:57:32      1504884
# contract-nli/raw/Non-Disclosure-Agreement-FORS-Cert-Body.pdf 2021-10-04 17:57:32        24159
# contract-nli/raw/1424657_0001213900-16-016691_f8k082516ex99iii_nextgroup.htm 2021-10-04 17:57:32        23571
# contract-nli/raw/OOR104E_Non-Disclosure_Agreement-Company.pdf 2021-10-04 17:57:32       421192
# contract-nli/raw/non-disclosure_201302814_english_.pdf 2021-10-04 17:57:32        16187
# contract-nli/raw/888953_0001193125-13-044630_d480503dex99e6.htm 2021-10-04 17:57:32        37916
# contract-nli/raw/clearcenter-rnda.pdf          2021-10-04 17:57:46        58231
# contract-nli/raw/NDA%20for%20Tender%20Ref%202201000050.pdf 2021-10-04 17:57:32        29158
# contract-nli/raw/Grindrod%20SA%20Confidentiality%20and%20Non-Disclosure%20Undertaking.pdf 2021-10-04 17:57:32        68133
# contract-nli/raw/1073090_0001356564-06-000012_sorell10ksbamend2x102.txt 2021-10-04 17:58:02        20854
# contract-nli/raw/1089786_0000912057-00-052660_a2032473zex-99_e2.txt 2021-10-04 17:57:32        15189
# contract-nli/raw/1029445_0000940180-97-000212_document_12.txt 2021-10-04 17:57:32        11945
# contract-nli/raw/1420529_0001145549-08-000077_h00839a1exv10w4.txt 2021-10-04 17:57:32        13809
# contract-nli/raw/QEP-Williston-Form-of-Confidentiality-Agreement-BMO.pdf 2021-10-04 17:57:32        45748
# contract-nli/raw/dhs-nda.pdf                   2021-10-04 17:58:02        32962
# contract-nli/raw/1609351_0001193125-19-066373_d642137dex99d2.htm 2021-10-04 17:57:32        30161
# contract-nli/raw/NondisclosureAgreement_2.pdf  2021-10-04 17:57:32       437870
# contract-nli/raw/non-disclosure-agreement_1.pdf 2021-10-04 17:57:32       195848
# contract-nli/raw/PSGT Agreement NDA New Supplier Non Disclosure Template DC.pdf 2021-10-04 17:57:32        79796
# contract-nli/raw/1013322_0000912057-00-023405_document_2.txt 2021-10-04 17:57:46         7310
# contract-nli/raw/MNDA.pdf                      2021-10-04 17:57:46       100527
# contract-nli/raw/IMOA%20Molybdenum%20Consortium%20NDA%20Agreement%20amended%20Jan%2008,%20valid%20March%2009%20onwards.pdf 2021-10-04 17:58:02        46855
# contract-nli/raw/nda_1.pdf                     2021-10-04 17:57:32        84729
# contract-nli/raw/JBF_NDA_rev-2017033-1.pdf     2021-10-04 17:57:32       197075
# contract-nli/raw/180314-March-14-2018-SOW-M.pdf 2021-10-04 17:57:46       537617
# contract-nli/raw/One-Way-Non-Disclosure-Agreement-EN.pdf 2021-10-04 17:57:32       390754
# contract-nli/raw/1142512_0001193125-14-269726_d757168dex99e3.htm 2021-10-04 17:57:32        26295
# contract-nli/raw/1023734_0000912057-96-023266_document_16.txt 2021-10-04 17:58:02         1963
# contract-nli/raw/1178133_0000950131-03-000129_dex1013.txt 2021-10-04 17:57:32        12190
# contract-nli/raw/eulerhermes-nda.pdf           2021-10-04 17:57:32       192000
# contract-nli/raw/Non-Disclosure-form_1.pdf     2021-10-04 17:58:02       593744
# contract-nli/raw/917639_0000912057-01-537118_a2062042zex-99_d7.htm 2021-10-04 17:57:46        29185
# contract-nli/raw/768384_0000912057-00-018619_document_8.txt 2021-10-04 17:58:02        10040
# contract-nli/raw/731947_0000950123-02-007159_y62132e3exv99wdw21.txt 2021-10-04 17:57:32         6106
# contract-nli/raw/1167294_0001193125-15-218134_d933068dex99d3.htm 2021-10-04 17:57:32        42565
# contract-nli/raw/Non_Disclosure_Agreement_1.pdf 2021-10-04 17:57:32       237409
# contract-nli/raw/1039399_0000891618-02-001883_f80848orex10-19.txt 2021-10-04 17:57:32        12077
# contract-nli/raw/Non-Disclosure-NDA-UW-Oshkosh_FINALV2.pdf 2021-10-04 17:57:32       163913
# contract-nli/raw/1475274_0001567619-17-000751_s001644x1_exd-2.htm 2021-10-04 17:57:32        41930
# contract-nli/raw/71297_0000071297-97-000059_document_6.txt 2021-10-04 17:58:02         4213
# contract-nli/raw/1277141_0001193125-15-184193_d923647dex99d2.htm 2021-10-04 17:57:32        42752
# contract-nli/raw/832995_0000912057-00-054331_a2033550zex-99_d13.htm 2021-10-04 17:57:32        26165
# contract-nli/raw/NDA-for-Gar-Kenyon-Suppliers.pdf 2021-10-04 17:57:32        44167
# contract-nli/raw/CA-Nov14-Doc.5.14%20-%20Template%20Confidentiality%20Agreement.pdf 2021-10-04 17:58:00       418793
# contract-nli/raw/1006459_0000912057-97-027623_document_19.txt 2021-10-04 17:57:32        77532
# contract-nli/raw/NDA-2016-DAB.pdf              2021-10-04 17:57:32       307978
# contract-nli/raw/1332602_0001193125-12-512465_d454990dex99d2.htm 2021-10-04 17:57:32        36783
# contract-nli/raw/1017545_0001012870-97-001500_document_2.txt 2021-10-04 17:57:32         4957
# contract-nli/raw/922913_0000943440-00-000122_document_2.txt 2021-10-04 17:57:32         4065
# contract-nli/raw/mcgill_mitacs_terms-january2013.pdf 2021-10-04 17:57:32       107586
# contract-nli/raw/ttp-nda.pdf                   2021-10-04 17:57:32        20707
# contract-nli/raw/eHandshake_Non_Disclosure_Agreement.pdf 2021-10-04 17:58:02        73380
# contract-nli/raw/Non-Disclosure_Agreement_oct2009.pdf 2021-10-04 17:57:32        10868
# contract-nli/raw/Non-Disclosure-Agreement-NDA.pdf 2021-10-04 17:58:02       103199
# contract-nli/raw/WECC_Confidentiality_Agreement.pdf 2021-10-04 17:57:32       183288
# contract-nli/raw/nda_pine__en.pdf              2021-10-04 17:57:32       117316
# contract-nli/raw/Non-Disclosure-Agreement_4.pdf 2021-10-04 17:57:32       100046
# contract-nli/raw/Confidentiality%20and%20Non-Disclosure%20Agreement%20%28CNA-1%29.pdf 2021-10-04 17:57:46        67024
# contract-nli/raw/NON_DISCLOSURE_AGREEMENT_5.pdf 2021-10-04 17:57:32       188983
# contract-nli/raw/817516_0001014909-05-000102_exh99_4sept2005.txt 2021-10-04 17:58:02        14512
# contract-nli/raw/SMT-R-100-01-NON-DISCLOSURE-AGREEMENT.pdf 2021-10-04 17:57:32       166260
# contract-nli/raw/32251_0000950133-99-003991_document_17.txt 2021-10-04 17:57:32        10869
# contract-nli/raw/Petrolube_NDA.pdf             2021-10-04 17:57:32       101489
# contract-nli/raw/Sample%20NDA%202018.pdf       2021-10-04 17:57:32        30382
# contract-nli/raw/Attachment B - Intent to Propose and Non-Disclosure Agreement.pdf 2021-10-04 17:58:00       164593
# contract-nli/raw/59b1148ff6952b0001bdbedc_20170907_non%20disclosure%20agreement_expert.pdf 2021-10-04 17:58:00       179937
# contract-nli/raw/41629_1.pdf                   2021-10-04 17:58:00       278516
# contract-nli/raw/ProtectedData-MMD-NonDisclosureAgreementSubmissionInstructions.pdf 2021-10-04 17:57:32       125387
# contract-nli/raw/NDA_5.pdf                     2021-10-04 17:57:32        52415
# contract-nli/raw/2_waycda.pdf                  2021-10-04 17:57:46        43986
# contract-nli/raw/1021096_0000914317-03-001205_ex2-2.txt 2021-10-04 17:57:32         8035
# contract-nli/raw/non-disclosure-agreement_5.pdf 2021-10-04 17:57:32        88883
# contract-nli/raw/Non-Disclosure_Agreement_one_way_2014.pdf 2021-10-04 17:57:32       100070
# contract-nli/raw/1062478_0001193125-14-442753_d838170dex3.htm 2021-10-04 17:58:02        19633
# contract-nli/raw/1016503_0000929624-00-000894_0010.txt 2021-10-04 17:57:46        13156
# contract-nli/raw/epsteen_nda.pdf               2021-10-04 17:57:32       494961
# contract-nli/raw/NMLS%20Accessibility%20NDA.pdf 2021-10-04 17:57:32       484027
# contract-nli/raw/1574111_0001193125-14-440569_d826999dex99d5.htm 2021-10-04 17:57:32        22966
# contract-nli/raw/Annex 18 - Non-Disclosure Agreement.pdf 2021-10-04 17:57:46       203544
# contract-nli/raw/Model%20NDA%20(recommended%20by%20SWA).pdf 2021-10-04 17:57:32        76726
# contract-nli/raw/1105503_0000950123-00-006736_ex10-14.txt 2021-10-04 17:57:32         8480
# contract-nli/raw/ICTSC-NDA-General-MandA-signed.pdf 2021-10-04 17:58:02       146282
# contract-nli/raw/1053949_0001005150-98-000126_document_8.txt 2021-10-04 17:57:32         5208
# contract-nli/raw/Disclosure documents.pdf      2021-10-04 17:57:32       138013
# contract-nli/raw/US-Non-Disclosure-Agreement.pdf 2021-10-04 17:57:32       181210
# contract-nli/raw/770461_0001144204-05-023830_v022988_ex10-6.txt 2021-10-04 17:57:32        14443
# contract-nli/raw/934545_0000891618-99-004640_document_2.txt 2021-10-04 17:58:02        27125
# contract-nli/raw/1095558_0000944209-00-000518_document_3.txt 2021-10-04 17:58:02        10409
# contract-nli/raw/Non-disclosure-Agreement_7.pdf 2021-10-04 17:57:32        56320
# contract-nli/raw/FELLCNDAStandardAgreement-22015.pdf 2021-10-04 17:57:32       296186
# contract-nli/raw/1043431_0000950133-00-000090_document_15.txt 2021-10-04 17:57:32         7795
# contract-nli/raw/Mutual%20Non-Disclosure%20Agreement.pdf 2021-10-04 17:57:32       135411
# contract-nli/raw/802724_0001193125-15-331613_d96542dex99d5.htm 2021-10-04 17:58:02        60587
# contract-nli/raw/1031896_0000950147-01-501725_ex10-8.txt 2021-10-04 17:57:32         2354
# contract-nli/raw/948850_0000950123-10-020820_p17071exv99wew4.htm 2021-10-04 17:57:32        25761
# contract-nli/raw/Mutual%20Non%20Disclosure%20Agreement_0.pdf 2021-10-04 17:57:32        40999
# contract-nli/raw/NDA_7.pdf                     2021-10-04 17:57:32        30741
# contract-nli/raw/Standard%20NDA%20by%20Axial.pdf 2021-10-04 17:57:32        33033
# contract-nli/raw/1012459_0000912057-97-027209_document_4.txt 2021-10-04 17:57:32         9217
# contract-nli/raw/Non-Disclosure-Agreement.pdf  2021-10-04 17:57:32        21973
# contract-nli/raw/NDA_6.pdf                     2021-10-04 17:57:32       106424
# contract-nli/raw/T:\proc_notices\notices_020_k\notice_doc_18628_158011843.pdf 2021-10-04 17:57:32       164927
# contract-nli/raw/1018761_0000950130-96-004285_document_6.txt 2021-10-04 17:57:32         2795
# contract-nli/raw/rqnda.pdf                     2021-10-04 17:57:32        28222
# contract-nli/raw/EUNCL_NDA_2016.pdf            2021-10-04 17:57:32       136293
# contract-nli/raw/Non-Disclosure-Agreement_6.pdf 2021-10-04 17:57:32       223394
# contract-nli/raw/1010471_0000950134-97-006281_document_5.txt 2021-10-04 17:58:02        24365
# contract-nli/raw/1466739_0001002014-12-000470_exh10-4.htm 2021-10-04 17:57:32        31802
# contract-nli/raw/1372664_0001193125-12-159071_d333885dex99d9.htm 2021-10-04 17:57:32        27996
# contract-nli/raw/simply-fashion---standard-nda.pdf 2021-10-04 17:57:32        16789
# contract-nli/raw/Tazza-CAFFE-Confidentiality-Agreement.pdf 2021-10-04 17:57:32       119693
# contract-nli/raw/NDA_English.pdf               2021-10-04 17:57:32       296845
# contract-nli/raw/NDA-M5-Systems.pdf            2021-10-04 17:57:32        70953
# contract-nli/raw/nda_template_final.pdf        2021-10-04 17:57:32       452414
# contract-nli/raw/NDA-Agreement-NPAF.pdf        2021-10-04 17:57:32       377878
# contract-nli/raw/1373671_0001193125-10-265249_dex99d3.htm 2021-10-04 17:57:32        33742
# contract-nli/raw/non-disclosure-agreement-mutual-generic-blank.pdf 2021-10-04 17:57:32        72682
# contract-nli/raw/OMA-TestFest-NDA-2017.pdf     2021-10-04 17:57:32       291483
# contract-nli/raw/SE_NDCA_and_PRE-QUAL_PACKAGE_March-2016.pdf 2021-10-04 17:57:32        73432
# contract-nli/raw/NUSD-Non-Disclosure-Agreement.pdf 2021-10-04 17:57:32        89425
# contract-nli/raw/non-disclosure-agreement-en.pdf 2021-10-04 17:58:02       103341
# contract-nli/raw/1052303_0000950109-98-003654_document_16.txt 2021-10-04 17:57:46         2718
# contract-nli/raw/1588052992CCTV%20Non%20Disclosure%20Agreement.pdf 2021-10-04 17:58:00       589436
# contract-nli/raw/1288379_0000950123-07-003101_y31044exv99wdw5.htm 2021-10-04 17:57:32        68176
# contract-nli/raw/1053352_0001104659-07-049383_a07-17151_1ex10d5.htm 2021-10-04 17:57:32        51224
# contract-nli/raw/96238_0000950103-97-000583_document_4.txt 2021-10-04 17:57:32        14762
# contract-nli/raw/amc-general-mutual-non-disclosure-agreement-en-gb.pdf 2021-10-04 17:58:00       150142
# contract-nli/raw/1111682_0000950123-00-003802_document_15.txt 2021-10-04 17:57:32         5080
# contract-nli/raw/1077150_0001077048-99-000003_document_25.txt 2021-10-04 17:57:32        10530
# contract-nli/raw/916529_0000927016-97-001071_document_2.txt 2021-10-04 17:57:32         5023
# contract-nli/raw/1001113_0000950134-07-005231_f27921orexv99wxdyx3y.htm 2021-10-04 17:58:02        12783
# contract-nli/raw/EFCAConfidentialityAgreement.pdf 2021-10-04 17:57:32        37229
# contract-nli/raw/1501697_0001193125-19-145463_d944716dex108.htm 2021-10-04 17:57:32         9777
# contract-nli/raw/Dealer-Pay-NDA-4.pdf          2021-10-04 17:57:32       536376
# contract-nli/raw/938733_0000912057-99-002412_document_3.txt 2021-10-04 17:57:32        15917
# contract-nli/raw/Template-NDA-2-way-final-1.pdf 2021-10-04 17:58:02        92945
# contract-nli/raw/935703_0001047469-98-030238_document_4.txt 2021-10-04 17:57:32        24404
# contract-nli/raw/858452_0001193125-12-123549_d317599dex99d3.htm 2021-10-04 17:57:32        36137
# contract-nli/raw/MutualNDA_Website.pdf         2021-10-04 17:57:32        82863
# contract-nli/raw/714562_0001104659-19-001345_a18-42231_6ex10d8.htm 2021-10-04 17:57:32        88144
# contract-nli/raw/ADVANIDE-NON-DISCLOSURE-AGREEMENT.pdf 2021-10-04 17:58:00      2894732
# contract-nli/raw/ingram-non-disclosure.pdf     2021-10-04 17:57:32        17487
# contract-nli/raw/Eskom%20Template%20Confidentiality%20and%20Non-disclosure%20Agreement%20Rev%204%20Effective%20August%202017_11.pdf 2021-10-04 17:57:32       231615
# contract-nli/raw/Mutual+Confidentiality+Agreement_1.pdf 2021-10-04 17:57:32       122931
# contract-nli/raw/NDA-Urban_Wind_Turbines.pdf   2021-10-04 17:58:02       153572
# contract-nli/raw/1067797_0001032210-99-000668_document_8.txt 2021-10-04 17:57:32        11590
# contract-nli/raw/RFP20171008-RFPPublishingNotice.pdf 2021-10-04 17:57:32       269251
# contract-nli/raw/1021097_0001047469-11-001653_a2202345zex-99_d10.htm 2021-10-04 17:57:46        29291
# contract-nli/raw/nondisclosureagreement.pdf    2021-10-04 17:57:32        14165
# contract-nli/raw/non-disclosure_confidentiality_agreement.pdf 2021-10-04 17:57:32        16366
# contract-nli/raw/confidentialityandnondisclosureagreement.pdf 2021-10-04 17:58:02       210305
# contract-nli/raw/1030471_0001012870-01-501268_dex1065.txt 2021-10-04 17:57:32         6207
# contract-nli/raw/1011344_0001193125-08-097987_dex99d5.htm 2021-10-04 17:58:02        14775
# contract-nli/raw/803647_0001047469-17-006266_a2233487zex-99_d2.htm 2021-10-04 17:57:32        27998
# contract-nli/raw/1253176_0001193125-18-317778_d567323dex1024.htm 2021-10-04 17:57:46        35533
# contract-nli/raw/Mutual%20confidentiality%20and%20NDA%20-%20Final%20(2)%20(6)%2003%20July%202015.pdf 2021-10-04 17:57:32       409005
# contract-nli/raw/1094017_0000921895-00-000237_document_5.txt 2021-10-04 17:57:32         8086
# contract-nli/raw/1288379_0000950123-07-003101_y31044exv99wdw6.htm 2021-10-04 17:57:32        55977
# contract-nli/raw/ceii-and-nda.pdf              2021-10-04 17:58:02       230467
# contract-nli/raw/non-disclosure-agreement_8.pdf 2021-10-04 17:57:32        79645
# contract-nli/raw/912263_0001193125-12-285724_d371520dex99e4.htm 2021-10-04 17:58:02        42945
# contract-nli/raw/CCS-Salt-Cavern-RfP-NDA.pdf   2021-10-04 17:58:00       110704
# contract-nli/raw/NonDisEC12212010.pdf          2021-10-04 17:57:32        23147
# contract-nli/raw/MelbourneDatathon2017NDA.pdf  2021-10-04 17:57:32       280479
# contract-nli/raw/Example-One-Way-Non-Disclosure-Agreement.pdf 2021-10-04 17:57:32        18790
# contract-nli/raw/for-41-supplier-confidentiality-agreement-and-non-disclosure-agreement.pdf 2021-10-04 17:57:32        69013
# contract-nli/raw/BTS_NDA.pdf                   2021-10-04 17:57:46        41978
# contract-nli/raw/87888_0000912057-97-029111_document_6.txt 2021-10-04 17:57:32        16902
# contract-nli/raw/912263_0001104659-12-004811_a12-3671_1ex2.htm 2021-10-04 17:57:32        62769
# contract-nli/raw/1485469_0001193125-19-222469_d760929dex99d3.htm 2021-10-04 17:57:32        66489
# contract-nli/raw/nda_8.pdf                     2021-10-04 17:57:32       126966
# contract-nli/raw/1074663_0001090002-01-500104_ex102.txt 2021-10-04 17:57:32         7149
# contract-nli/raw/Mutual-Non-Disclosure-Agreement-Inventor-Product-Development-Experts-Inc..pdf 2021-10-04 17:58:02       412422
# contract-nli/raw/NDA-ONSemi_IndustryAnalystConf-2011.pdf 2021-10-04 17:57:32       507311
# contract-nli/raw/NDAMutualTemplateClientFill.pdf 2021-10-04 17:58:02        31199
# contract-nli/raw/5-NSK-Confidentiality-Agreement-for-Suppliers.pdf 2021-10-04 17:58:00       262565
# contract-nli/raw/BaconNon-Disclosure.pdf       2021-10-04 17:58:00       928206
# contract-nli/raw/NDA_template.pdf              2021-10-04 17:57:32       447509
# contract-nli/raw/nda_9.pdf                     2021-10-04 17:58:02        58042
# contract-nli/raw/1084817_0001193125-14-004957_d648340dex99e2.htm 2021-10-04 17:58:02        17227
# contract-nli/raw/NDA_V3.pdf                    2021-10-04 17:58:02        79485
# contract-nli/raw/1021086_0000950162-99-000581_document_3.txt 2021-10-04 17:58:02        20874
# contract-nli/raw/930796_0000950123-05-001407_y05539exv99w5.txt 2021-10-04 17:57:32        13719
# contract-nli/raw/AfriGIS_Client-NDA_Template_2019.pdf 2021-10-04 17:58:00        96497
# contract-nli/raw/1062579_0000950123-99-005018_document_3.txt 2021-10-04 17:57:32        19604
# contract-nli/raw/NDA%20UDRC%203-way%20Final.pdf 2021-10-04 17:57:32        91408
# contract-nli/raw/NDATyre%20Plant.pdf           2021-10-04 17:57:32       229334
# contract-nli/raw/CI-Non-Disclosure-Agreement-an5h.pdf 2021-10-04 17:57:46       105924
# contract-nli/raw/741696_0001193125-10-290887_dex99d9.htm 2021-10-04 17:57:32        29445
# contract-nli/raw/Non-disclosure-Agreement_9.pdf 2021-10-04 17:57:32        97975
# contract-nli/raw/770461_0001144204-06-041516_v054278_ex10-7.txt 2021-10-04 17:57:32        16324
# contract-nli/raw/HALO-NDA.pdf                  2021-10-04 17:57:32       105568
# contract-nli/raw/1044777_0000950124-98-000388_document_7.txt 2021-10-04 17:57:32         2508
# contract-nli/raw/1438076025NDA_28072015%20-%20AHPL.pdf 2021-10-04 17:57:46       137317
# contract-nli/raw/NDA.pdf                       2021-10-04 17:57:32        71551
# contract-nli/raw/36C25520Q0076-013.pdf         2021-10-04 17:57:46       138966
# contract-nli/raw/NDA_118.pdf                   2021-10-04 17:57:32        57789
# contract-nli/raw/Non-Disclosure-Agreement-9-1-2018.pdf 2021-10-04 17:57:32       263507
# contract-nli/raw/GreenStorm%20NDCSC.pdf        2021-10-04 17:57:32        95354
# contract-nli/raw/1120792_0001019687-05-002206_morgan_10qex5-2.txt 2021-10-04 17:58:02         9008
# contract-nli/raw/354452_0000950123-99-011178_document_13.txt 2021-10-04 17:57:32        12428
# contract-nli/raw/NDA%20Form%20WEB_WITH%20Instructions%20%28RECIPROCAL%29%20%28v%202016-03-18_EN%29.pdf 2021-10-04 17:57:32       240945
# contract-nli/raw/880458_0001021408-01-510269_dex1087.txt 2021-10-04 17:58:02        29283
# contract-nli/raw/BT_NDA.pdf                    2021-10-04 17:58:00        31725
# contract-nli/raw/1177845_0001193125-18-219243_d519554dex99d3.htm 2021-10-04 17:57:32        39764
# contract-nli/raw/UT_Universal_NDA_2014_OIE.pdf 2021-10-04 17:57:32       191260
# contract-nli/raw/NDA-Seeed.pdf                 2021-10-04 17:57:32       132020
# contract-nli/raw/1077150_0001077048-99-000003_document_23.txt 2021-10-04 17:57:32         3943
# contract-nli/raw/vmw-certification-conduct-policy.pdf 2021-10-04 17:57:32        37995
# contract-nli/raw/1063085_0000950134-09-011390_f52580exv99wxeyx3y.htm 2021-10-04 17:57:32        31550
# contract-nli/raw/NDA-editable.pdf              2021-10-04 17:57:32        22422
# contract-nli/raw/1017358_0001017358-97-000002_document_4.txt 2021-10-04 17:57:32         9808
# contract-nli/raw/non-disclosure-agreement-template-netherlands-may-2012.pdf 2021-10-04 17:57:32       154004
# contract-nli/raw/Non-Disclosure-Agreement_PreviewOnly.pdf 2021-10-04 17:57:32       194124
# contract-nli/raw/1285543_0001013762-05-000550_may52005sb2ex1019.txt 2021-10-04 17:57:32         7363
# contract-nli/raw/1628908_0001193125-15-169530_d838828dex1016.htm 2021-10-04 17:57:32        89487
# contract-nli/raw/1274644_0001193125-17-338759_d485523dex99d2.htm 2021-10-04 17:57:32        21187
# contract-nli/raw/HNBA-2017-18-Confidentiality-Agreement.pdf 2021-10-04 17:57:32        26934
# contract-nli/raw/nondisclosure.pdf             2021-10-04 17:57:32        70073
# contract-nli/raw/75448_0001193125-05-158309_dex99d4.htm 2021-10-04 17:57:32        25552
# contract-nli/raw/Confidentiality%20ND%20Agreement%209.pdf 2021-10-04 17:57:46       170281
# contract-nli/raw/Example-Mutual-Non-Disclosure-Agreement.pdf 2021-10-04 17:57:32        17771
# contract-nli/raw/1108244_0001012870-00-001650_document_32.txt 2021-10-04 17:57:46         4680
# contract-nli/raw/1109551_0000912057-02-024714_a2082535zex-99_d3.htm 2021-10-04 17:58:02        29146
# contract-nli/raw/Lead-NDA.pdf                  2021-10-04 17:57:32       681624
# contract-nli/raw/130806ca141.pdf               2021-10-04 17:58:00       449341
# contract-nli/raw/912263_0001047469-12-006662_a2209873zex-99_d2.htm 2021-10-04 17:58:02        63118
# contract-nli/raw/Non-Disclosure-SmartCMS.pdf   2021-10-04 17:57:32       202873
# contract-nli/raw/Annex E_Non-Disclosure and Confidentiality Agreement.pdf 2021-10-04 17:57:32        96523
# contract-nli/raw/Confidentiality_Non-Disclosure_Agreement.pdf 2021-10-04 17:58:02        19943
# contract-nli/raw/3511_standard_nda.pdf         2021-10-04 17:57:46        26150
# contract-nli/raw/NDD.pdf                       2021-10-04 17:57:32        65918
# contract-nli/raw/NDA-No-Reservations-Layer-8-Security.pdf 2021-10-04 17:57:46       136193
# contract-nli/raw/1334303_0001193125-10-204560_dex99e5.htm 2021-10-04 17:57:46        36245
# contract-nli/raw/1070052_0000950130-01-501801_dex99d2.txt 2021-10-04 17:57:32        14795
# contract-nli/raw/1041550_0001104659-19-001346_a18-42231_6ex10d8.htm 2021-10-04 17:57:32        88144
# contract-nli/raw/LiiON%20NDA%202-27-2015%20v1.0.pdf 2021-10-04 17:57:32       134763
# contract-nli/raw/1045080_0001047469-02-004620_a2094681zex-99_d5.htm 2021-10-04 17:57:32        16550
# contract-nli/raw/1120792_0001019687-05-001599_morgan_sb2a1-ex1408.txt 2021-10-04 17:57:32         9072
# contract-nli/raw/Focus-Group-APIC-Seattle-Confidentiality-Agreement-031115.pdf 2021-10-04 17:57:32        67646
# contract-nli/raw/Attachment-I-Non-DisclosureAgreementContractor.pdf 2021-10-04 17:58:00        39348
# contract-nli/raw/14803_0001047469-04-012846_a2134202zex-99_e3.htm 2021-10-04 17:57:32        25982
# contract-nli/raw/nda2.pdf                      2021-10-04 17:57:32        90211
# contract-nli/raw/Attachment%20J.2%20-%20Non-Disclosure%20Agreement%20-Technology%20Services.pdf 2021-10-04 17:58:00        14863
# contract-nli/raw/mnda-1110.pdf                 2021-10-04 17:57:32        99636
# contract-nli/raw/54c808c1b20e4490b1300ad2ce3b9649.pdf 2021-10-04 17:58:00       197841
# contract-nli/raw/769592_0000950133-02-003341_w64132exv10w4.txt 2021-10-04 17:57:32         7790
# contract-nli/raw/Attachment 9 -  Non Disclosure Agreement (Version 1).pdf 2021-10-04 17:57:46        88843
# contract-nli/raw/form_NondisclosureBlanket.pdf 2021-10-04 17:57:32        25537
# contract-nli/raw/1592288_0001193125-17-306543_d469659dex99e2.htm 2021-10-04 17:57:32        37024
# contract-nli/raw/1094348_0001144204-18-026846_tv493416_exd2.htm 2021-10-04 17:57:32        36229
# contract-nli/raw/Data Use Agreement New York City.pdf 2021-10-04 17:57:32       470940
# contract-nli/raw/1335239_0001019687-14-003760_epazz_ex1034.htm 2021-10-04 17:58:02        39302
# contract-nli/raw/874265_0001193125-05-138436_dex99d1.htm 2021-10-04 17:57:32        36295
# contract-nli/raw/813562_0000950117-99-001205_document_14.txt 2021-10-04 17:57:46         7847
# contract-nli/raw/1062760_0001015402-05-001930_doc17.txt 2021-10-04 17:57:32         7090
# contract-nli/raw/Confidentiality-and-Nondisclosure-Agreement-Template.pdf 2021-10-04 17:58:02        44757
# contract-nli/raw/PS20131165-Non-DisclosureAgreement.pdf 2021-10-04 17:57:32        29951
# contract-nli/raw/Confidentiality-and-Non-Disclosure-Agreement-LSI-ABC.pdf 2021-10-04 17:57:46        44454
# contract-nli/raw/Basic-Non-Disclosure-Agreement.pdf 2021-10-04 17:58:00        28899
# contract-nli/raw/18268-001%20Rev%20B%20Form%20Version%20in%20PDF.pdf 2021-10-04 17:58:00       243802
# contract-nli/raw/915191_0001047469-17-003155_a2231967zex-99_8.htm 2021-10-04 17:58:02        32528
# contract-nli/raw/NDA-CRG-ALL-2.pdf             2021-10-04 17:57:32       280607
# contract-nli/raw/1065748_0000950131-00-004465_0016.txt 2021-10-04 17:57:32         7484
# contract-nli/raw/NDA-SqillerBetaTesters.pdf    2021-10-04 17:57:32       115126
# contract-nli/raw/Business-Sale-Non-Disclosure-Agreement.pdf 2021-10-04 17:58:00        75098
# contract-nli/raw/01_Bosch-Automotive-Service-Solutions-Mutual-Non-Disclosure-Agreement-7-12-17.pdf 2021-10-04 17:58:00       109931
# contract-nli/raw/oceaneering-non-disclosure-agreement.pdf 2021-10-04 17:57:32       103595
# contract-nli/raw/FNHA-2019RFP-02-NDA-form.pdf  2021-10-04 17:57:32       236091
# contract-nli/raw/modelnondisclosureagreement1.pdf 2021-10-04 17:57:32        37744
# contract-nli/raw/DBT%20Mutual%20NDA.pdf        2021-10-04 17:57:32       120069
# contract-nli/raw/913949_0000950149-96-000782_document_6.txt 2021-10-04 17:57:32         4082
# contract-nli/raw/NDA-Prasad.pdf                2021-10-04 17:57:32        31400
# contract-nli/raw/816955_0000899243-97-001962_document_4.txt 2021-10-04 17:57:32        16949
# contract-nli/raw/NDA-standard.pdf              2021-10-04 17:57:32       383164
# contract-nli/raw/NDA_Sample.pdf                2021-10-04 17:57:32        11971
# contract-nli/raw/nistmodelndareceiptofproprietaryinformationv20162fillableforwebsitedoc003pdf.pdf 2021-10-04 17:57:32       170878
# contract-nli/raw/MUTUAL-NDA-Form-2.pdf         2021-10-04 17:57:32        46078
# contract-nli/raw/thoughtbot-mutual-nda.pdf     2021-10-04 17:57:32        97481
# contract-nli/raw/US_Non-Disclosure_Agreement_v2_2015.pdf 2021-10-04 17:57:32        28326
# contract-nli/raw/356841_0000950109-98-003750_document_2.txt 2021-10-04 17:57:32         5838
# contract-nli/raw/Agreement_6_28_07.pdf         2021-10-04 17:57:46       119251
# contract-nli/raw/703339_0001387308-13-000090_ex101.htm 2021-10-04 17:57:32        48503
# contract-nli/raw/Acme%20Corporation%20Inc%20NDA%20template.pdf 2021-10-04 17:57:46       185052
# contract-nli/raw/1689602_0001144204-16-140940_v455386_ex10-3.htm 2021-10-04 17:57:32        38781
# contract-nli/raw/925942_0001047469-98-029396_document_13.txt 2021-10-04 17:57:32        13703
# contract-nli/raw/GTC_CEII_Non_Disclosure_Agmt_05111_revised.pdf 2021-10-04 17:57:32       204438
# contract-nli/raw/1413447_0001193125-16-771498_d295023dex99d5.htm 2021-10-04 17:57:32        42566
# contract-nli/raw/MUTUAL-NON-CIRCUMVENT-and-NON-DISCLOSURE-20.pdf 2021-10-04 17:57:32       173938
# contract-nli/raw/Confidentiality_and_Non-Disclosure_Agreement.pdf 2021-10-04 17:57:46        79038
# contract-nli/raw/1085220_0001014909-04-000090_exh6_3.txt 2021-10-04 17:57:32         7719
# contract-nli/raw/1119985_0001047469-04-035924_a2147858zex-2_5.htm 2021-10-04 17:57:32        23641
# contract-nli/raw/NU%20Confidentiality%20Non-Disclosure%20%20Information%20Security%20Agreement%20Final%20....pdf 2021-10-04 17:57:32       269350
# contract-nli/raw/183.pdf                       2021-10-04 17:57:46        84789
# contract-nli/raw/CNDA1218Draft3.pdf            2021-10-04 17:57:46       231675
# contract-nli/raw/buyer_profile.pdf             2021-10-04 17:58:00       195878
# contract-nli/raw/GSAOP0309-Non-disclosure-agreement.pdf 2021-10-04 17:57:32       298920
# contract-nli/raw/nda_gtl_inria.pdf             2021-10-04 17:57:32       115313
# contract-nli/raw/1392091_0000950123-11-021325_c13551exv99w7.htm 2021-10-04 17:57:46        18647
# contract-nli/raw/65781_0000950123-00-009565_y41542ex99-d_3.txt 2021-10-04 17:58:02         9698
# contract-nli/raw/1373467_0001096350-07-000140_ex99threea.htm 2021-10-04 17:57:32        19509
# contract-nli/raw/document_viewer.pdf           2021-10-04 17:57:32       151466
# contract-nli/raw/NON-Disclosure_Agreement_2.pdf 2021-10-04 17:57:32       100160
# contract-nli/raw/INFOMAGNET%20NDA.pdf          2021-10-04 17:57:32        97556
# contract-nli/raw/792130_0001193125-18-326077_d601641dex99d3.htm 2021-10-04 17:57:32        36332
# contract-nli/raw/1100182_0001107049-00-000014_document_23.txt 2021-10-04 17:57:32         8056
# contract-nli/raw/Kerber_Non_Disclosure_Agreement.pdf 2021-10-04 17:57:32        21942
# contract-nli/raw/1011671_0000936392-99-000246_document_46.txt 2021-10-04 17:58:02        11119
# contract-nli/raw/NDA_ResConnect.pdf            2021-10-04 17:58:02        86038
# contract-nli/raw/1289434_0001047469-10-008010_a2200117zex-99_d3.htm 2021-10-04 17:57:46        77619
# contract-nli/raw/ExcelerateStandardNDAFormat.pdf 2021-10-04 17:57:32       214064
# contract-nli/raw/1012887_0001193125-07-165503_dex99d6.htm 2021-10-04 17:58:02        20796
# contract-nli/raw/BO115-07-non-disclosure-agreement.pdf 2021-10-04 17:58:00       815278
# contract-nli/raw/NDA_for_Raffles_Translation_Website.pdf 2021-10-04 17:57:32       216502
# contract-nli/raw/801338_0000950134-07-015617_c16542toexv99wxdyx5y.htm 2021-10-04 17:57:32        12699
# contract-nli/raw/Startup_Pack_nondisclosure_agreement.pdf 2021-10-04 17:57:32        32317
# contract-nli/raw/appendix-g-nda-form.pdf       2021-10-04 17:58:00       177272
# contract-nli/raw/96238_0000950116-97-001823_document_13.txt 2021-10-04 17:58:02        14590
# contract-nli/raw/example-NDA-one-way-short-form-2012-1.pdf 2021-10-04 17:57:32        17582
# contract-nli/raw/casino-nondisclosure-agmt.pdf 2021-10-04 17:58:00      1437339
# contract-nli/raw/86115_0000930661-99-001321_document_3.txt 2021-10-04 17:58:02        23510
# contract-nli/raw/NRSC_2015_NDAForm.pdf         2021-10-04 17:57:32       154161
# contract-nli/raw/NDA_Mutual_template2_5_2019.pdf 2021-10-04 17:57:32        68373
# contract-nli/raw/Template-NDA.pdf              2021-10-04 17:57:32        99791
# contract-nli/raw/WEB-NDA-Mutual-Customer-and-Allazo-Electronics-v2.pdf 2021-10-04 17:57:32        86353
# contract-nli/raw/1001917_0000950123-08-007542_y61533exv99wdw3.htm 2021-10-04 17:57:32        19373
# contract-nli/raw/69067_0000927016-00-002123_0010.txt 2021-10-04 17:57:32         9415
# contract-nli/raw/1123713_0001021408-00-003137_0016.txt 2021-10-04 17:57:32        12222
# contract-nli/raw/1138169_0001050234-02-000002_ex10h.txt 2021-10-04 17:58:02         8884
# contract-nli/raw/NDA_22.pdf                    2021-10-04 17:57:32        34151
# contract-nli/raw/Generic-NDA-Pitch-Deck-Fire.pdf 2021-10-04 17:58:02       138768
# contract-nli/raw/FormEConfidentialityandNon.pdf 2021-10-04 17:57:32        70617
# contract-nli/raw/1049210_0001047469-13-009461_a2216846zex-99_d3.htm 2021-10-04 17:58:02        32655
# contract-nli/raw/non-disclosure_agreement_1.pdf 2021-10-04 17:57:32        37587
# contract-nli/raw/VELCO%20NDA%20rev0%20Dec%2014%202015.pdf 2021-10-04 17:58:02       115652
# contract-nli/raw/Pitch-Deck-Fire-Workshop-NDA-2.2017.pdf 2021-10-04 17:58:02       344619
# contract-nli/raw/1043003_0000950170-98-000097_document_12.txt 2021-10-04 17:58:02         5352
# contract-nli/raw/26820_0000936392-03-001111_a92217exv10w5.txt 2021-10-04 17:57:32        17564
# contract-nli/raw/IGC-Non-Disclosure-Agreement-LSE-Sample.pdf 2021-10-04 17:57:32       582984
# contract-nli/raw/Section%2013%20Non-Disclosure%20Agreement.pdf 2021-10-04 17:57:32        76466
# contract-nli/raw/1112999_0001193125-08-214471_dex105.htm 2021-10-04 17:57:32        19098
# contract-nli/raw/LSP-data-protection-form.drc_.pdf 2021-10-04 17:57:32       177777
# contract-nli/raw/NonDisclosureAgreementNDASAMITT20190002v2.pdf 2021-10-04 17:58:02       157177
# contract-nli/raw/17.04.01%20BPS%20Non-Disclosure%20and%20Data%20Sharing%20Agreement%20-%20Transportation%20Challenge%20vF.pdf 2021-10-04 17:57:46       255478
# contract-nli/raw/MUTUAL_NDA.pdf                2021-10-04 17:58:02       171859
# contract-nli/raw/5-Appendix-Non-Disclosure-Agreement-Mutual.pdf 2021-10-04 17:57:46       103123
# contract-nli/raw/900091_0001047469-97-003029_document_4.txt 2021-10-04 17:57:32        10978
# contract-nli/raw/NDA-Artop-Inno-2017.pdf       2021-10-04 17:57:32        48691
# contract-nli/raw/QuickBooks-NDA-template.pdf   2021-10-04 17:57:32        56219
# contract-nli/raw/1367408_0001367408-06-000002_risb2ex105.htm 2021-10-04 17:57:32         2856
# contract-nli/raw/1113303_0000892917-12-000026_stilffnw13d120112am2ex3.htm 2021-10-04 17:57:32        24690
# contract-nli/raw/mutual_non_disclosure_agreement-20171020.pdf 2021-10-04 17:57:32        43459
# contract-nli/raw/IBC-PMS-NDA-agreement.pdf     2021-10-04 17:57:32        37601
# contract-nli/raw/850313_0000950149-07-000090_f28028toexv99wxdyx2y.htm 2021-10-04 17:58:02        19586
# contract-nli/raw/Non-Disclosure-form.pdf       2021-10-04 17:57:32       115661
# contract-nli/raw/resolution-2012-03-014r.pdf   2021-10-04 17:57:32       330404
# contract-nli/raw/912890_0001193125-11-030842_dex99d5.htm 2021-10-04 17:57:46        26181
# contract-nli/raw/lti-two-way-cda-template.pdf  2021-10-04 17:57:32        33837
# contract-nli/raw/non-disclosure-agreement-template.pdf 2021-10-04 17:58:02       150113
# contract-nli/raw/LMS_Non_Disclosure_Agreement.pdf 2021-10-04 17:58:02        56297
# contract-nli/raw/NDA_-_GWI_-_Technohubs_version_V1.pdf 2021-10-04 17:57:32       121599
# contract-nli/raw/Confidentiality%20Agreement.pdf 2021-10-04 17:58:02        51385
# contract-nli/raw/1013687_0000950144-96-001973_document_38.txt 2021-10-04 17:57:32         9706
# contract-nli/raw/Confidentiality.pdf           2021-10-04 17:57:46       120343
# contract-nli/raw/5bfbcabf0627e70bdcfc5b32_nda-ready4s.pdf 2021-10-04 17:58:00        98740
# contract-nli/raw/UALR-Standard-Non-disclosure-AgreementTemplate.pdf 2021-10-04 17:58:02       180938
# contract-nli/raw/Third-Party Non-Disclosure Agreement.pdf 2021-10-04 17:57:32        48931
# contract-nli/raw/12032018_NDA_The%20Munt_EN.pdf 2021-10-04 17:58:00       142394
# contract-nli/raw/Confidentiality_Agreement_1.pdf 2021-10-04 17:58:02        15250
# contract-nli/raw/1050277_0001047469-99-000663_document_7.txt 2021-10-04 17:58:02         2898
# contract-nli/raw/Florida-Non-Disclosure-Agreement-NDA-Template.pdf 2021-10-04 17:57:32       111207
# contract-nli/raw/TSE-TSE-OK-WHK-Mutual-NDA-Fill-in-Blanks-4-29-2019.pdf 2021-10-04 17:57:32       156721
# contract-nli/raw/1042282_0000893220-02-000791_e61414toexv99wxdywx1y.txt 2021-10-04 17:58:02         8174
# contract-nli/raw/MUTUAL-CONFIDENTIAL-NON-DISCLOSURE.pdf 2021-10-04 17:57:32       396988
# contract-nli/raw/ 064-19 Non Disclosure Agreement 2019.pdf 2021-10-04 17:58:00       461261
# contract-nli/raw/804151_0000950144-97-007563_document_14.txt 2021-10-04 17:57:46        15638
# contract-nli/raw/one-way_nda_ji_form.pdf       2021-10-04 17:57:32       703699
# contract-nli/raw/1046880_0001193125-11-323050_d262064dex992.htm 2021-10-04 17:57:32        26671
# contract-nli/raw/1096182_0001144204-06-021678_v043804_ex10-3.txt 2021-10-04 17:57:46        13559
# contract-nli/raw/RFP_Telephony-NDA_Attachment-F.pdf 2021-10-04 17:57:32        18498
# contract-nli/raw/1430300_0000950152-08-005260_l32384aexv10w7.htm 2021-10-04 17:57:32         3992
# contract-nli/raw/1323115_0000950123-10-098499_c60911exv99wdw3.htm 2021-10-04 17:57:32        19363
# contract-nli/raw/1013240_0001047469-04-010350_a2132633zex-10_22.htm 2021-10-04 17:57:32        60340
# contract-nli/raw/RROI_Confidentiality_Agreement_Final.pdf 2021-10-04 17:57:32       333290
# contract-nli/raw/1316898_0001047469-18-005618_a2236490zex-99_d2.htm 2021-10-04 17:58:02        55171
# contract-nli/raw/1367408_0001367408-06-000002_risb2ex106.htm 2021-10-04 17:58:02         6320
# contract-nli/raw/1280058_0001193125-12-023311_d287213dex99d3.htm 2021-10-04 17:57:32        34105
# contract-nli/raw/Evelozcity%20OESA%20NDA.pdf   2021-10-04 17:57:32       113349
# contract-nli/raw/245490.pdf                    2021-10-04 17:57:46        50458
# contract-nli/raw/nda_19.pdf                    2021-10-04 17:57:32         9917
# contract-nli/raw/TabunKitchenInvestments-NDA.pdf 2021-10-04 17:57:32      1042757
# contract-nli/raw/1102301_0001094328-04-000141_freesarex23052004.txt 2021-10-04 17:57:32         9442
# contract-nli/raw/1010552_0000912057-01-520246_a2051644zex-99_20.htm 2021-10-04 17:58:02        27912
# contract-nli/raw/sample_nda.pdf                2021-10-04 17:57:32       161378
# contract-nli/raw/103884_0001193125-12-338104_d390544dex99d3.htm 2021-10-04 17:57:32        25999
# contract-nli/raw/897730_0000950136-98-001457_document_7.txt 2021-10-04 17:57:32         8476
# contract-nli/raw/partner_nda_en.pdf            2021-10-04 17:57:32       177445
# contract-nli/raw/912592_0000929624-98-000842_document_20.txt 2021-10-04 17:57:32        14194
# contract-nli/raw/sm-fm-14-01-rev-1-reciprocal-non-disclosure-agreement.pdf 2021-10-04 17:57:32       154101
# contract-nli/raw/1363033_0001144204-06-024852_v045245_ex10-8.htm 2021-10-04 17:57:32        22707
# contract-nli/raw/JHUNDABilateral.pdf           2021-10-04 17:57:32        78263
# contract-nli/raw/NDA-Fintricity-Blank.pdf      2021-10-04 17:57:32      1431930
# contract-nli/raw/standard_clinical_trial_nda2.pdf 2021-10-04 17:57:32       781809
# contract-nli/raw/BCG-Mutual-NDA.pdf            2021-10-04 17:58:00       413804
# contract-nli/raw/863895_0001144204-05-038795_v030731_ex10-2.htm 2021-10-04 17:57:32        19732
# contract-nli/raw/1014552_0000950148-01-500497_v71961toex99-d3.txt 2021-10-04 17:57:32        21086
# contract-nli/raw/859792_0001005477-96-000681_document_3.txt 2021-10-04 17:57:46        10261
# contract-nli/raw/P27CB13028.pdf                2021-10-04 17:57:32        30673
# contract-nli/raw/1402305_0001193125-11-343865_d268167dex99d2.htm 2021-10-04 17:58:02        27243
# contract-nli/raw/920729_0000891618-96-000819_document_6.txt 2021-10-04 17:57:32        12250
# contract-nli/raw/ws-confidentiality-and-non-disclosure-agreement.pdf 2021-10-04 17:57:32       183018
# contract-nli/raw/WEBSITE%20MNDA.pdf            2021-10-04 17:57:32       438714
# contract-nli/raw/NDATC.pdf                     2021-10-04 17:57:32        61930
# contract-nli/raw/DoiT-ICN-NonDisclosure-Agreement.pdf 2021-10-04 17:57:32        86324
# contract-nli/raw/883905_0001095811-01-000469_f68556ex99-d12.txt 2021-10-04 17:58:02         7552
# contract-nli/raw/SupplementOne-NDA.pdf         2021-10-04 17:57:32       381115
# contract-nli/raw/859119_0000950123-98-001418_document_15.txt 2021-10-04 17:57:32        16809
# contract-nli/raw/703361_0001193125-12-242586_d356019dex9910.htm 2021-10-04 17:57:32        28168
# contract-nli/raw/Cyber Mutual Assistance NDA.pdf 2021-10-04 17:57:32        53658
# Extracting all the files now...
# Done!

# %%
def get_sent1_token_type(sent):
    try:
        return [0]* len(sent)
    except:
        return []

def get_sent2_token_type(sent):
    try:
        return [1]* len(sent)
    except:
        return []
    
def combine_seq(seq):
    return " ".join(seq)

def combine_mask(mask):
    mask = [str(m) for m in mask]
    return " ".join(mask)

# %%
from typing import List, Tuple
import enum


label2index = {"Entailment":1,"NotMentioned":0,"Contradiction":2}


class ContractNLIExample:
    """
    A single training/test example for the contract NLI.

    Args:
        data_id: The example's unique identifier
        hypothesis_text: The hypothesis string
        context_text: The context string
        answer_text: The answer string
        start_position_character: The character position of the start of the answer
    """

    def __init__(
        self,
        *,
        data_id,
        document_id,
        hypothesis_id,
        file_name,
        hypothesis_text,
        hypothesis_tokens,
        context_text,
        tokens,
        splits,
        spans,
        char_to_word_offset,
        label,
        annotated_spans
    ):
        self.data_id: str = data_id
        self.document_id: str = document_id
        self.hypothesis_id: str = hypothesis_id
        self.hypothesis_symbol: str = f'[{hypothesis_id}]'
        self.file_name: str = file_name
        self.hypothesis_text: str = hypothesis_text
        self.hypothesis_tokens: List[str] = hypothesis_tokens
        self.context_text: str = context_text
        self.tokens: List[str] = tokens
        # Note that splits are NOT unique
        self.splits: List[int] = splits
        self.spans: List[Tuple[int, int]] = spans
        self.char_to_word_offset: List[int] = char_to_word_offset
        self.label: int = label
        self.annotated_spans: List[int] = annotated_spans

    @staticmethod
    def tokenize_and_align(text: str, spans: List[Tuple[int, int]]):
        """
        spans: Spans as character offsets. e.g. "world" in "Hello, world" will
            be represented as (7, 12).
        """
        # Split on whitespace so that different tokens may be attributed to their original position.
        tokens = []
        char_to_word_offset = []
        prev_is_whitespace = True
        splits = {si for s in spans for si in s}

        for i, c in enumerate(text):
            if c == ' ':
                # splits will be ignored on space
                prev_is_whitespace = True
            else:
                if prev_is_whitespace or i in splits:
                    tokens.append(c)
                else:
                    tokens[-1] += c
                prev_is_whitespace = False
            # len(tokens) == 0 when first characters are spaces
            char_to_word_offset.append(max(len(tokens) - 1, 0))
        
        splits = [char_to_word_offset[s[0]] for s in spans]
        return tokens, splits, char_to_word_offset

    @classmethod
    def load(cls, input_data) -> List['ContractNLIExample']:
        examples = []
        label_dict = {
            label_id: label_info['hypothesis']
            for label_id, label_info in input_data['labels'].items()}
        for document in tqdm(input_data['documents']):
            if len(document['annotation_sets']) != 1:
                raise RuntimeError(
                    f'{len(document["annotation_sets"])} annotation sets given but '
                    'we only support single annotation set.')
            for label_id, annotation in document['annotation_sets'][0]['annotations'].items():
                data_id = f'{document["id"]}_{label_id}'
                context_text = document['text']
                hypothesis_text = label_dict[label_id]

                tokens, splits, char_to_word_offset = cls.tokenize_and_align(
                    context_text, document['spans'])
                hypothesis_tokens, _, _ = cls.tokenize_and_align(
                    hypothesis_text, [])
                assert len(splits) == len(document['spans'])
                example = cls(
                    data_id=data_id,
                    document_id=document["id"],
                    hypothesis_id=label_id,
                    file_name=document['file_name'],
                    hypothesis_text=hypothesis_text,
                    hypothesis_tokens=hypothesis_tokens,
                    context_text=context_text,
                    tokens=tokens,
                    splits=splits,
                    spans=document['spans'],
                    char_to_word_offset=char_to_word_offset,
                    label=label2index[annotation['choice']],
                    annotated_spans=annotation['spans']
                )
                examples.append(example)
        return examples

# %%
SPAN_TOKEN = "[SPAN]"

def addAdditionalToken(token_tobe_added):
    if (token_tobe_added not in additional_tokens):
        additional_tokens.append(token_tobe_added)
        tokenizer.add_special_tokens({'additional_special_tokens': tokenizer.additional_special_tokens + [token_tobe_added]})

addAdditionalToken(SPAN_TOKEN)

# %%
import json
def getExamples(dataset_name='train'):
    path=f'/content/contract-nli/{dataset_name}.json' 
    with open(path) as fin:
        input_dict = json.load(fin)
    examples = ContractNLIExample.load(input_dict)
    return examples

# %%
def preprocessingContract(examples, SPAN_TOKEN, l = 300, n = 20):
    max_length=332
    data_examples = {"sequence": [], "label": [], "span_position_vector": [], "span_index_vector": [], "span_attention_hypothesis": [] ,"attention_mask":[], "token_type":[] }
    # print(len(examples))
    for i_example in examples:
        # x+=1
        updated_text = ""
        for i in i_example.spans:
            updated_text += " " + SPAN_TOKEN + " " + i_example.context_text[i[0]:i[1]]
        
        start = 0
        current_span_index = 0
        end = -1
        prevpos = 0
        tokenized_text = tokenize_bert(updated_text)
        prevstart = start
        hypo_token = tokenize_bert(i_example.hypothesis_text)
        while(end < len(tokenized_text)-1):

            span_position_vector = []
            span_index_vector = []
            span_attention_hypothesis = []
            temstart = start
            curcontext = []
            prevpos = -1
            for i in range(start, min(start+l, len(tokenized_text))):
                if(tokenized_text[i] == SPAN_TOKEN):
                    span_position_vector.append(1)
                    span_index_vector.append(current_span_index)
                    if(current_span_index in i_example.annotated_spans):
                        span_attention_hypothesis.append(1)
                    else:
                        span_attention_hypothesis.append(0)
                    temstart = i
                    current_span_index += 1
                    prevpos = i-start
                else:
                    span_position_vector.append(0)
                    span_index_vector.append(0)
                    span_attention_hypothesis.append(0)
                curcontext.append(tokenized_text[i])

                end = i
            


            if(end < len(tokenized_text) -1 ):
                if(tokenized_text[end+1] == SPAN_TOKEN):
                    if (prevpos != -1):
                        span_position_vector[prevpos] = 0
                        span_index_vector[prevpos] = 0
                        span_attention_hypothesis[prevpos] = 0

            # print(prevstart, start)
            if(temstart==start):
                start += n
            else:
                start = temstart - n 
            
            if(prevstart == start):
                start += n
            prevstart = start

            for i in range(end, temstart - n - 1, -1):
                if(tokenized_text[i] == SPAN_TOKEN):
                    current_span_index -= 1
            # print(i_example.spans[current_span_index])
            token_type = [0]*(len(curcontext)+2) + [1]*(len(hypo_token)+1)
            curcontext = [init_token] + curcontext + [eos_token] + hypo_token + [eos_token]
            curlen = max_length - len(curcontext)
            attention_mask = [1]*len(curcontext) + [0]*curlen
            curcontext += [pad_token] * curlen
            span_position_vector = [0] + span_position_vector + [0] * (len(hypo_token)+2 + curlen)
            token_type += [1]*curlen
            span_index_vector = [0] + span_index_vector + [0] * (len(hypo_token)+2+curlen)
            span_attention_hypothesis = [0] + span_attention_hypothesis + [0] * (len(hypo_token)+2+curlen)
            
            if(sum(span_attention_hypothesis) == 0):
                continue

            # max_length = max(max_length, len(curcontext))
            data_examples["sequence"].append(tokenizer.convert_tokens_to_ids(curcontext))
            data_examples["label"].append(i_example.label)            
            data_examples["span_position_vector"].append(span_position_vector)            
            data_examples["span_index_vector"].append(span_index_vector)            
            data_examples["span_attention_hypothesis"].append(span_attention_hypothesis) 
            data_examples["attention_mask"].append(attention_mask)
            data_examples["token_type"].append(token_type)

               
    # print(max_length)
    return data_examples

# %%
train_examples = getExamples("train")
train_dataset = preprocessingContract(train_examples,SPAN_TOKEN)
del train_examples
# print(max_len)

# if len(train_dataset["sequence"][0]) != len(train_dataset["span_position_vector"][0]):
#     print("FAILURE")

# for i in range(len(train_dataset["span_position_vector"][0])):
#     if train_dataset["span_position_vector"][0][i] == 1:
#         print(train_dataset["sequence"][0][i])

dev_examples = getExamples("dev")
dev_dataset=[]
for i in tqdm(dev_examples):
    dev_dataset.append(preprocessingContract([i],SPAN_TOKEN))
del dev_examples

test_examples = getExamples("test")
test_dataset=[]
for i in tqdm(test_examples):
    test_dataset.append(preprocessingContract([i],SPAN_TOKEN))
del test_examples
# Out:
# 100%|██████████| 423/423 [00:53<00:00,  7.95it/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (1909 > 512). Running this sequence through the model will result in indexing errors
# 100%|██████████| 61/61 [00:09<00:00,  6.61it/s]
# 100%|██████████| 1037/1037 [00:12<00:00, 82.07it/s]
# 100%|██████████| 123/123 [00:10<00:00, 11.40it/s]
# 100%|██████████| 2091/2091 [00:26<00:00, 79.74it/s]

# %%
# print(max_len)

# %%
BATCH_SIZE = 8

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def getDataloader(dataset):
    sequence = torch.tensor(dataset["sequence"],dtype=torch.long)
    attention_mask = torch.tensor(dataset["attention_mask"],dtype=torch.long)
    token_type = torch.tensor(dataset["token_type"],dtype=torch.long)
    label = torch.tensor(dataset["label"],dtype=torch.long)
    span_position_vector = torch.tensor(dataset["span_position_vector"],dtype=torch.long)
    span_index_vector = torch.tensor(dataset["span_index_vector"],dtype=torch.long)
    span_attention_hypothesis = torch.tensor(dataset["span_attention_hypothesis"],dtype=torch.long)

    dataset = torch.utils.data.TensorDataset(sequence, label, span_position_vector, span_index_vector, span_attention_hypothesis ,attention_mask, token_type)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)
    return dataloader
  
train_dataloader = getDataloader(train_dataset)
valid_dataloader = []
test_dataloader = []
for i in dev_dataset:
    # print(i)
    if len(i["label"]) != 0:
        valid_dataloader.append(getDataloader(i))
for i in test_dataset:
    if len(i["label"]) != 0:
        test_dataloader.append(getDataloader(i))

# %%
from transformers import AutoModel

bert_model = AutoModel.from_pretrained(model_name,output_hidden_states=True, add_pooling_layer=True)
bert_model.resize_token_embeddings(len(tokenizer))
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Embedding(30523, 768)

# %%
import torch.nn as nn

class BERTNLIModel(nn.Module):
    def __init__(self,
                 bert_model,
                 hidden_dim,
                 output_dim,
                ):
        
        super().__init__()
        
        self.bert = bert_model
        
        embedding_dim = bert_model.config.to_dict()['hidden_size']

        self.class_outputs = nn.Linear(embedding_dim, 3)
        self.span_outputs = nn.Linear(embedding_dim, 2)
        print(bert_model.config.hidden_dropout_prob)
        print(bert_model.config.hidden_size)
        self.dropout = nn.Dropout(bert_model.config.hidden_dropout_prob)
        self.activation2 = nn.Sigmoid()
        self.activation1 = nn.Softmax()


    def forward(self, sequence, attn_mask, token_type):
        output = self.bert(input_ids = sequence, attention_mask = attn_mask, token_type_ids= token_type)
        last_hidden_state = output.last_hidden_state
        last_hidden_state = self.dropout(last_hidden_state)
        span_out = self.span_outputs(last_hidden_state)
        span_out = self.activation2(span_out)

        pooler_output = output.pooler_output
        pooler_output = self.dropout(pooler_output)
        label_out = self.class_outputs(pooler_output)
        label_out = self.activation1(label_out)

        return span_out, label_out

# %%
HIDDEN_DIM = 512
OUTPUT_DIM = len(label2index)

model = BERTNLIModel(bert_model,HIDDEN_DIM,OUTPUT_DIM,).to(device)
# Out:
# 0.1
# 768

# %%
from transformers import *
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation_utils.py:24: FutureWarning: Importing `GenerationMixin` from `src/transformers/generation_utils.py` is deprecated and will be removed in Transformers v5. Import as `from transformers import GenerationMixin` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation_tf_utils.py:24: FutureWarning: Importing `TFGenerationMixin` from `src/transformers/generation_tf_utils.py` is deprecated and will be removed in Transformers v5. Import as `from transformers import TFGenerationMixin` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation_flax_utils.py:24: FutureWarning: Importing `FlaxGenerationMixin` from `src/transformers/generation_flax_utils.py` is deprecated and will be removed in Transformers v5. Import as `from transformers import FlaxGenerationMixin` instead.
#   warnings.warn(
# Xformers is not installed correctly. If you want to use memorry_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
import torch.optim as optim

#optimizer = optim.Adam(model.parameters())
optimizer = AdamW(model.parameters(),lr=2e-5,eps=1e-6,correct_bias=False)

def get_scheduler(optimizer, warmup_steps):
    scheduler = get_constant_schedule_with_warmup(optimizer, num_warmup_steps=warmup_steps)
    return scheduler
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
criterion = nn.CrossEntropyLoss().to(device)

# %%
def categorical_accuracy(preds, y):
    max_preds = preds.argmax(dim = 1, keepdim = True) # get the index of the max probability
    correct = (max_preds.squeeze(1)==y).float()
    return correct.sum() / len(y)

# %%
max_grad_norm = 1

def train(model, iterator, optimizer, criterion, scheduler, weight_span=0.1):
    #print(iterator)
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.train()
    
    for sequence, label, span_position_vector, span_index_vector, span_attention_hypothesis ,attn_mask, token_type in tqdm(iterator):

        optimizer.zero_grad() # clear gradients first
        torch.cuda.empty_cache() # releases all unoccupied cached memory 
        
        sequence,attn_mask,token_type,label = sequence.to(device),attn_mask.to(device),token_type.to(device),label.to(device)
        # span_position_vector, span_index_vector, span_attention_hypothesis = span_position_vector.to(device), span_index_vector.to(device), span_attention_hypothesis.to(device)
        
        predictions_span, predictions_label = model(sequence, attn_mask, token_type)

        final_list=[]
        
        # print(predictions_span)

        # print(predictions_span.shape)
        for i in range(len(predictions_span)):
            predictions_span[i] = torch.mul(predictions_span[i].clone().T, span_position_vector[i].clone()).T        
            # print(predictions_span[i].shape)

            spv = torch.unsqueeze(span_position_vector[i].clone(),0)
            
            # print(spv.shape)
            spah = torch.unsqueeze(span_attention_hypothesis[i].clone(),0)

            true_span =  torch.cat([spah, spv- spah]).T
            # print(true_span.shape)
            true_span = torch.unsqueeze(true_span,0)
            # print(true_span.shape)
            
            final_list.append(true_span)

        final_true_span= torch.cat(final_list)
        final_true_span = final_true_span.to(device) 

        # print(predictions_span)

        loss_span = criterion(predictions_span,  torch.tensor(final_true_span,dtype=torch.float))
        loss_label = None
        # print(span_attention_hypothesis[0].shape)
        for i in range(len(label)):
            
            if torch.sum(span_attention_hypothesis[i]) >= 1:
                if loss_label != None:
                    loss_label += criterion(predictions_label[i], label[i])
                else:
                    loss_label = criterion(predictions_label[i], label[i])

        # loss = loss_label + weight_span * loss_span
        if loss_label == None:
            continue
        loss = loss_label + weight_span * loss_span
        
        acc = categorical_accuracy(predictions_label, label)
        loss.backward()
        
        optimizer.step()
        scheduler.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd



def categorical_accuracy1(preds, y):
    max_preds = preds.argmax() # get the index of the max probability
    correct = (max_preds==y)
    return correct


def evaluate(model, iterator, criterion):
    #print(iterator)
    epoch_loss = 0
    epoch_acc = 0
    y_true = [torch.tensor(0), torch.tensor(1), torch.tensor(2)]
    y_pred = [torch.tensor(0), torch.tensor(1), torch.tensor(2)]
    model.eval()
    
    with torch.no_grad():
        for itl in tqdm(iterator):
            pl = torch.zeros(3).to(device)
            wt = 0
            llabel = None
            for sequence, labels, span_position_vector, span_index_vector, span_attention_hypothesis ,attn_mask, token_type in itl:

                sequence,attn_mask,token_type,labels = sequence.to(device),attn_mask.to(device),token_type.to(device),labels.to(device)
                predictions_span, predictions_label = model(sequence, attn_mask, token_type)
                for i in range(len(predictions_label)):
                    temwt = torch.sum(span_attention_hypothesis)/torch.sum(span_position_vector)
                    pl = pl + temwt.to(device) * predictions_label[i]
                    wt += temwt                    
                llabel = labels[0]

            pl = pl/wt
            pl =  torch.mul(pl, torch.tensor([0,1,1]).to(device))
            # print(pl)
            # print(llabel)
            # print(pl.cpu().argmax())
            loss = criterion(pl, llabel)
            y_true.append(llabel.cpu())
                
            y_pred.append(pl.cpu().argmax())
            acc = categorical_accuracy1(pl, llabel)
            
            epoch_loss += loss.item()
            epoch_acc += acc.item()
        # print("Test Classification report")
        # print(y_true)
        # print(y_pred)
        # print(classification_report(y_true, y_pred, target_names=["NotMentioned","Entailment","Contradiction"]))
        # cf_matrix = confusion_matrix(y_true, y_pred)
        # df_cm = pd.DataFrame(cf_matrix / np.sum(cf_matrix, axis=1)[:, None], index = [i for i in ["NotMentioned","Entailment","Contradiction"]],columns = [i for i in ["NotMentioned","Entailment","Contradiction"]])
        # # plt.figure(figsize = (12,7))
        # sn.heatmap(df_cm, annot=True)
        # plt.savefig('output.png')
        # plt.show()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
import time

def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
import math
N_EPOCHS = 6

warmup_percent = 0.2
total_steps = math.ceil(N_EPOCHS*len(train_dataset)*1./BATCH_SIZE)
warmup_steps = int(total_steps*warmup_percent)
scheduler = get_scheduler(optimizer, warmup_steps)

best_valid_loss = float('inf')
best_epoch=0

for epoch in range(N_EPOCHS):

    start_time = time.time()
    
    train_loss, train_acc = train(model, train_dataloader, optimizer, criterion, scheduler)
    valid_loss, valid_acc = evaluate(model, valid_dataloader, criterion)
    
    end_time = time.time()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        best_epoch=epoch
    torch.save(model.state_dict(), f'/content/gdrive/MyDrive/NLPProject/models/bert-cnli_{epoch}.pt')
    
    print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f}%')
# Out:
#   0%|          | 0/868 [00:00<?, ?it/s]<ipython-input-22-c777078c67a7>:35: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   label_out = self.activation1(label_out)
# 100%|██████████| 868/868 [08:16<00:00,  1.75it/s]
# 100%|██████████| 614/614 [00:23<00:00, 25.99it/s]
# Epoch: 01 | Epoch Time: 8m 40s
# 	Train Loss: 5.880 | Train Acc: 81.64%
# 	 Val. Loss: 0.706 |  Val. Acc: 84.53%
# 100%|██████████| 868/868 [08:20<00:00,  1.73it/s]
# 100%|██████████| 614/614 [00:23<00:00, 26.00it/s]
# Epoch: 02 | Epoch Time: 8m 44s
# 	Train Loss: 5.862 | Train Acc: 81.80%
# 	 Val. Loss: 0.706 |  Val. Acc: 84.53%
# 100%|██████████| 868/868 [08:21<00:00,  1.73it/s]
# 100%|██████████| 614/614 [00:23<00:00, 26.06it/s]
# Epoch: 03 | Epoch Time: 8m 44s
# 	Train Loss: 5.862 | Train Acc: 81.83%
# 	 Val. Loss: 0.706 |  Val. Acc: 84.53%
# 100%|██████████| 868/868 [08:20<00:00,  1.73it/s]
# 100%|██████████| 614/614 [00:23<00:00, 25.98it/s]
# Epoch: 04 | Epoch Time: 8m 44s
# 	Train Loss: 5.862 | Train Acc: 81.83%
# 	 Val. Loss: 0.706 |  Val. Acc: 84.53%
# 100%|██████████| 868/868 [08:20<00:00,  1.73it/s]
# 100%|██████████| 614/614 [00:23<00:00, 26.14it/s]
# Epoch: 05 | Epoch Time: 8m 44s
# 	Train Loss: 5.862 | Train Acc: 81.83%
# 	 Val. Loss: 0.706 |  Val. Acc: 84.53%
# 100%|██████████| 868/868 [08:20<00:00,  1.73it/s]
# 100%|██████████| 614/614 [00:23<00:00, 25.98it/s]
# Epoch: 06 | Epoch Time: 8m 44s
# 	Train Loss: 5.862 | Train Acc: 81.80%
# 	 Val. Loss: 0.706 |  Val. Acc: 84.53%

# %%
model.load_state_dict(torch.load(f'/content/gdrive/MyDrive/NLPProject/models/bert-cnli_5.pt'))

test_loss, test_acc = evaluate(model, test_dataloader, criterion)

print(f'Test Loss: {test_loss:.3f} |  Test Acc: {test_acc*100:.2f}%')
# Out:
#   0%|          | 0/1188 [00:00<?, ?it/s]<ipython-input-22-c777078c67a7>:35: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   label_out = self.activation1(label_out)
# 100%|██████████| 1188/1188 [00:45<00:00, 26.14it/s]
# Test Loss: 0.737 |  Test Acc: 81.48%
